# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Read Parquet") \
    .getOrCreate()

parquet_path = "/home/jovyan/notebooks/spark/sensor_data/merged_sensor_parquet_hourly/*.parquet"

df = spark.read.parquet(parquet_path)
df.show(100000, truncate=False)
# Out:
# +----------+-------------------+--------------------+-----+-----+-----------------+
# |station_id|reading_date       |datetime_from_sensor|value|unit |air_quality_class|
# +----------+-------------------+--------------------+-----+-----+-----------------+
# |10955     |2025-06-03 19:52:34|2025-06-01 05:00:00 |28.8 |µg/m³|dobry            |
# |530       |2025-06-03 19:52:34|2025-06-01 05:00:00 |29.2 |µg/m³|dobry            |
# |10956     |2025-06-03 19:52:34|2025-06-01 05:00:00 |21.7 |µg/m³|dobry            |
# |550       |2025-06-03 19:52:33|2025-06-01 06:00:00 |22.9 |µg/m³|dobry            |
# |552       |2025-06-03 19:52:34|2025-06-01 06:00:00 |22.5 |µg/m³|dobry            |
# |10955     |2025-06-03 19:52:34|2025-06-01 06:00:00 |29.0 |µg/m³|dobry            |
# |530       |2025-06-03 19:52:34|2025-06-01 06:00:00 |26.1 |µg/m³|dobry            |
# |10956     |2025-06-03 19:52:34|2025-06-01 06:00:00 |22.8 |µg/m³|dobry            |
# ...
